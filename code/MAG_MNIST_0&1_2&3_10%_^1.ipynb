# %%
print("test")
# Out:
# test

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback
import matplotlib.pyplot as plt
import pandas as pd

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU is available and memory growth is set.")
    except RuntimeError as e:
        print(e)

tf.keras.mixed_precision.set_global_policy('mixed_float16')

# Load the MNIST dataset
(img_train, label_train), (img_test, label_test) = tf.keras.datasets.mnist.load_data()

# Filter out images of digits "2" and "3" for training and testing datasets
train_filter_2_3 = (label_train == 2) | (label_train == 3)
test_filter_2_3 = (label_test == 2) | (label_test == 3)

img_train_2_3, label_train_2_3 = img_train[train_filter_2_3], label_train[train_filter_2_3]
img_test_2_3, label_test_2_3 = img_test[test_filter_2_3], label_test[test_filter_2_3]

# Convert labels to one-hot encoded vectors with 2 classes
label_train_2_3 = tf.keras.utils.to_categorical(label_train_2_3 - 2, num_classes=2)
label_test_2_3 = tf.keras.utils.to_categorical(label_test_2_3 - 2, num_classes=2)

# Filter out images of digits "0" and "1" for validation datasets
val_filter_0_1 = (label_test == 0) | (label_test == 1)

img_val_0_1, label_val_0_1 = img_test[val_filter_0_1], label_test[val_filter_0_1]

# Convert labels to one-hot encoded vectors with 2 classes for validation
label_val_0_1 = tf.keras.utils.to_categorical(label_val_0_1, num_classes=2)

# Function to convert grayscale images to RGB and resize them to 224x224
def preprocess_image(image, label):
    image = tf.expand_dims(image, axis=-1)  # Expand to add the channel dimension (28, 28) -> (28, 28, 1)
    image = tf.image.grayscale_to_rgb(image)  # Convert to RGB by repeating the channel (28, 28, 1) -> (28, 28, 3)
    image = tf.image.resize(image, (224, 224))  # Resize to 224x224
    image = image / 255.0  # Normalize to [0, 1]
    return image, label

# Convert the training and testing datasets into TensorFlow datasets
train_dataset_2_3 = tf.data.Dataset.from_tensor_slices((img_train_2_3, label_train_2_3))
test_dataset_2_3 = tf.data.Dataset.from_tensor_slices((img_test_2_3, label_test_2_3))

# Convert the validation dataset into TensorFlow dataset
val_dataset_0_1 = tf.data.Dataset.from_tensor_slices((img_val_0_1, label_val_0_1))

# Apply the preprocessing function
train_dataset_2_3 = train_dataset_2_3.map(preprocess_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
test_dataset_2_3 = test_dataset_2_3.map(preprocess_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
val_dataset_0_1 = val_dataset_0_1.map(preprocess_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)

# Batch the datasets
batch_size = 32
train_dataset_2_3 = train_dataset_2_3.shuffle(buffer_size=10000).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)
test_dataset_2_3 = test_dataset_2_3.batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)
val_dataset_0_1 = val_dataset_0_1.batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)

# Load the pre-trained model
pretrained_model_path = 'MNIST_vgg16_0&1.h5'
pretrained_model = load_model(pretrained_model_path)

# Load the model with freezing rates
freezing_model_path = 'freezing_value_mag_0&1_10%_^1.h5'
freezing_model = load_model(freezing_model_path)

# Extract the freezing rates from the model weights
freezing_weights = [layer.get_weights() for layer in freezing_model.layers if layer.get_weights()]

# Define the fixed learning rate
fixed_learning_rate = 0.00001

# Define a custom optimizer with learning rate adjustment
class CustomAdam(Adam):
    def __init__(self, learning_rate, freezing_weights, *args, **kwargs):
        super(CustomAdam, self).__init__(learning_rate, *args, **kwargs)
        self.freezing_weights = freezing_weights
        self.learning_rate = learning_rate

    def _resource_apply_dense(self, grad, var, apply_state=None):
        var_key = self._var_key(var)
        freezing_weight = None

        for layer_weight in self.freezing_weights:
            if var.name in layer_weight[0].name:
                freezing_weight = layer_weight[0]
                break

        if freezing_weight is not None:
            learning_rate_new = self.learning_rate * freezing_weight
            return super(CustomAdam, self)._resource_apply_dense(grad, var, apply_state={
                "lr_t": learning_rate_new
            })
        else:
            return super(CustomAdam, self)._resource_apply_dense(grad, var, apply_state)

# Initialize the custom optimizer
custom_optimizer = CustomAdam(learning_rate=fixed_learning_rate, freezing_weights=freezing_weights)

# Display the pre-trained model summary
pretrained_model.summary()

# Compile the model with the custom optimizer
pretrained_model.compile(optimizer=custom_optimizer,
                         loss='categorical_crossentropy',
                         metrics=['accuracy'])

# Custom callback to validate on "0" and "1" validation set and save the model at the 10th epoch
class ZeroOneValidationAndSaveCallback(Callback):
    def __init__(self, validation_data):
        super(ZeroOneValidationAndSaveCallback, self).__init__()
        self.validation_data = validation_data
        self.val_loss_0_1 = []
        self.val_accuracy_0_1 = []

    def on_epoch_end(self, epoch, logs=None):
        val_loss, val_accuracy = self.model.evaluate(self.validation_data, verbose=0)
        self.val_loss_0_1.append(val_loss)
        self.val_accuracy_0_1.append(val_accuracy)
        print(f'\nEpoch {epoch + 1}: val_loss_0_1 = {val_loss}, val_accuracy_0_1 = {val_accuracy}\n')
        # Save the model at the 10th epoch
        if epoch + 1 == 10:
            self.model.save('MAG_MNIST_vgg16_0&1_2&3_10%.h5')

# Initialize the custom callback
zero_one_validation_callback = ZeroOneValidationAndSaveCallback(val_dataset_0_1)

# Train the model without early stopping for 20 epochs
history = pretrained_model.fit(
    train_dataset_2_3,
    epochs=10,
    validation_data=test_dataset_2_3,
    callbacks=[zero_one_validation_callback]
)

# Evaluate the model on the "2" and "3" test dataset
loss_2_3, accuracy_2_3 = pretrained_model.evaluate(test_dataset_2_3)
print(f"Test Loss on 2&3: {loss_2_3}")
print(f"Test Accuracy on 2&3: {accuracy_2_3}")

# Evaluate the model on the "0" and "1" validation dataset
loss_0_1, accuracy_0_1 = pretrained_model.evaluate(val_dataset_0_1)
print(f"Validation Loss on 0&1: {loss_0_1}")
print(f"Validation Accuracy on 0&1: {accuracy_0_1}")

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 8))

epochs = range(1, len(history.history['accuracy']) + 1)

plt.subplot(2, 2, 1)
plt.plot(epochs, history.history['accuracy'], label='Train Accuracy')
plt.plot(epochs, history.history['val_accuracy'], label='Validation Accuracy on 2&3')
plt.title('Model Accuracy on 2&3')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(epochs, history.history['loss'], label='Train Loss')
plt.plot(epochs, history.history['val_loss'], label='Validation Loss on 2&3')
plt.title('Model Loss on 2&3')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(epochs, zero_one_validation_callback.val_accuracy_0_1, label='Validation Accuracy on 0&1')
plt.title('Model Accuracy on 0&1')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(epochs, zero_one_validation_callback.val_loss_0_1, label='Validation Loss on 0&1')
plt.title('Model Loss on 0&1')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# Create a dataframe to list training and validation accuracy and loss for all epochs
history_df = pd.DataFrame(history.history)
history_df['epoch'] = history_df.index + 1
history_df['val_loss_0_1'] = zero_one_validation_callback.val_loss_0_1
history_df['val_accuracy_0_1'] = zero_one_validation_callback.val_accuracy_0_1
history_df = history_df[['epoch', 'accuracy', 'val_accuracy', 'loss', 'val_loss', 'val_loss_0_1', 'val_accuracy_0_1']]
print(history_df)
# Out:
# 2024-08-05 20:19:24.042273: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-05 20:19:24.654382: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-05 20:19:24.865685: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-05 20:19:24.928082: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-05 20:19:25.362701: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-05 20:19:27.411819: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1722889170.944458    1512 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1722889171.373688    1512 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1722889171.376760    1512 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# Num GPUs Available:  1
# GPU is available and memory growth is set.
# I0000 00:00:1722889171.688477    1512 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1722889171.691452    1512 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1722889171.693970    1512 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1722889171.872000    1512 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1722889171.873068    1512 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1722889171.874023    1512 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-05 20:19:31.876009: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13775 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:1e.0, compute capability: 7.5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4096)           │   102,764,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4096)           │    16,781,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │         8,194 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 134,268,744 (512.19 MB)
#  Trainable params: 134,268,738 (512.19 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 6 (36.00 B)
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1722889184.831615    1549 service.cc:146] XLA service 0x7f91a801cbb0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1722889184.831665    1549 service.cc:154]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2024-08-05 20:19:44.953388: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-08-05 20:19:45.777939: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# 2024-08-05 20:19:50.433051: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[32,224,224,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,224,224,64]{3,2,1,0}, f16[64,3,3,64]{3,2,1,0}, f16[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:19:57.282564: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 7.84958756s
# Trying algorithm eng0{} for conv (f16[32,224,224,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,224,224,64]{3,2,1,0}, f16[64,3,3,64]{3,2,1,0}, f16[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:19:59.098889: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[32,112,112,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,112,112,64]{3,2,1,0}, f16[128,3,3,64]{3,2,1,0}, f16[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:20:01.121019: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 3.022218316s
# Trying algorithm eng0{} for conv (f16[32,112,112,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,112,112,64]{3,2,1,0}, f16[128,3,3,64]{3,2,1,0}, f16[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:20:10.198101: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[32,224,224,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,224,224,64]{3,2,1,0}, f16[64,3,3,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:20:17.117051: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 7.919024958s
# Trying algorithm eng0{} for conv (f16[32,224,224,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,224,224,64]{3,2,1,0}, f16[64,3,3,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:20:18.864596: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[64,3,3,4]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,224,224,4]{3,2,1,0}, f16[32,224,224,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:20:20.168652: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.304131691s
# Trying algorithm eng0{} for conv (f16[64,3,3,4]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,224,224,4]{3,2,1,0}, f16[32,224,224,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:20:23.248511: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{} for conv (f16[64,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,224,224,64]{3,2,1,0}, f16[32,224,224,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:20:34.824695: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 12.576250232s
# Trying algorithm eng19{} for conv (f16[64,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,224,224,64]{3,2,1,0}, f16[32,224,224,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:20:36.847084: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{} for conv (f16[128,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,112,112,64]{3,2,1,0}, f16[32,112,112,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:20:40.711462: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 4.864464403s
# Trying algorithm eng19{} for conv (f16[128,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,112,112,64]{3,2,1,0}, f16[32,112,112,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:20:42.733390: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{} for conv (f16[128,3,3,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,112,112,128]{3,2,1,0}, f16[32,112,112,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:20:57.747251: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 16.013933235s
# Trying algorithm eng19{} for conv (f16[128,3,3,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,112,112,128]{3,2,1,0}, f16[32,112,112,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:20:59.013684: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{} for conv (f16[256,3,3,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,56,56,128]{3,2,1,0}, f16[32,56,56,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:20:59.244767: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.231157312s
# Trying algorithm eng19{} for conv (f16[256,3,3,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,56,56,128]{3,2,1,0}, f16[32,56,56,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:21:00.889582: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{} for conv (f16[256,3,3,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,56,56,256]{3,2,1,0}, f16[32,56,56,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:21:02.328437: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.438929676s
# Trying algorithm eng19{} for conv (f16[256,3,3,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,56,56,256]{3,2,1,0}, f16[32,56,56,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:21:03.547543: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{} for conv (f16[512,3,3,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,28,28,256]{3,2,1,0}, f16[32,28,28,512]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:21:03.873111: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.325636376s
# Trying algorithm eng19{} for conv (f16[512,3,3,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,28,28,256]{3,2,1,0}, f16[32,28,28,512]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:21:05.435558: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{} for conv (f16[512,3,3,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,28,28,512]{3,2,1,0}, f16[32,28,28,512]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:21:06.950082: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.514590934s
# Trying algorithm eng19{} for conv (f16[512,3,3,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,28,28,512]{3,2,1,0}, f16[32,28,28,512]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
#   1/378 ━━━━━━━━━━━━━━━━━━━━ 10:01:16 96s/step - accuracy: 0.5312 - loss: 4.9168
# I0000 00:00:1722889273.030894    1549 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 377/378 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.7813 - loss: 1.4978
# 2024-08-05 20:22:18.146124: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[25,224,224,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[25,224,224,64]{3,2,1,0}, f16[64,3,3,64]{3,2,1,0}, f16[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:22:23.499555: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 6.353504115s
# Trying algorithm eng0{} for conv (f16[25,224,224,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[25,224,224,64]{3,2,1,0}, f16[64,3,3,64]{3,2,1,0}, f16[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:22:25.263082: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[25,112,112,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[25,112,112,64]{3,2,1,0}, f16[128,3,3,64]{3,2,1,0}, f16[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:22:26.674241: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.411227642s
# Trying algorithm eng0{} for conv (f16[25,112,112,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[25,112,112,64]{3,2,1,0}, f16[128,3,3,64]{3,2,1,0}, f16[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:22:34.660229: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[25,224,224,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[25,224,224,64]{3,2,1,0}, f16[64,3,3,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:22:39.958507: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 6.298339822s
# Trying algorithm eng0{} for conv (f16[25,224,224,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[25,224,224,64]{3,2,1,0}, f16[64,3,3,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:22:41.865359: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[64,3,3,4]{3,2,1,0}, u8[0]{0}) custom-call(f16[25,224,224,4]{3,2,1,0}, f16[25,224,224,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:22:42.587588: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.722297226s
# Trying algorithm eng0{} for conv (f16[64,3,3,4]{3,2,1,0}, u8[0]{0}) custom-call(f16[25,224,224,4]{3,2,1,0}, f16[25,224,224,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:22:45.396543: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{} for conv (f16[64,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[25,224,224,64]{3,2,1,0}, f16[25,224,224,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:22:52.056872: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 7.660396776s
# Trying algorithm eng19{} for conv (f16[64,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[25,224,224,64]{3,2,1,0}, f16[25,224,224,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:22:53.888207: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{} for conv (f16[128,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[25,112,112,64]{3,2,1,0}, f16[25,112,112,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:22:55.987972: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 3.099833847s
# Trying algorithm eng19{} for conv (f16[128,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[25,112,112,64]{3,2,1,0}, f16[25,112,112,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:22:57.710138: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{} for conv (f16[128,3,3,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[25,112,112,128]{3,2,1,0}, f16[25,112,112,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:23:04.734574: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 8.024505816s
# Trying algorithm eng19{} for conv (f16[128,3,3,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[25,112,112,128]{3,2,1,0}, f16[25,112,112,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:23:07.395115: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{} for conv (f16[256,3,3,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[25,56,56,256]{3,2,1,0}, f16[25,56,56,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:23:08.408410: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.013362141s
# Trying algorithm eng19{} for conv (f16[256,3,3,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[25,56,56,256]{3,2,1,0}, f16[25,56,56,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:23:09.596844: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{} for conv (f16[512,3,3,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[25,28,28,256]{3,2,1,0}, f16[25,28,28,512]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:23:09.608373: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.011597338s
# Trying algorithm eng19{} for conv (f16[512,3,3,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[25,28,28,256]{3,2,1,0}, f16[25,28,28,512]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:23:11.055692: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{} for conv (f16[512,3,3,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[25,28,28,512]{3,2,1,0}, f16[25,28,28,512]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:23:12.067841: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.01221804s
# Trying algorithm eng19{} for conv (f16[512,3,3,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[25,28,28,512]{3,2,1,0}, f16[25,28,28,512]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.7817 - loss: 1.4951
# 2024-08-05 20:23:20.779629: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[32,224,224,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,224,224,64]{3,2,1,0}, f16[64,3,3,64]{3,2,1,0}, f16[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:23:27.912448: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 8.132891904s
# Trying algorithm eng0{} for conv (f16[32,224,224,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,224,224,64]{3,2,1,0}, f16[64,3,3,64]{3,2,1,0}, f16[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:23:29.800584: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[32,112,112,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,112,112,64]{3,2,1,0}, f16[128,3,3,64]{3,2,1,0}, f16[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:23:31.888454: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 3.087947422s
# Trying algorithm eng0{} for conv (f16[32,112,112,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[32,112,112,64]{3,2,1,0}, f16[128,3,3,64]{3,2,1,0}, f16[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:23:43.439702: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[26,224,224,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[26,224,224,64]{3,2,1,0}, f16[64,3,3,64]{3,2,1,0}, f16[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:23:49.062769: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 6.623130897s
# Trying algorithm eng0{} for conv (f16[26,224,224,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[26,224,224,64]{3,2,1,0}, f16[64,3,3,64]{3,2,1,0}, f16[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:23:50.897967: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[26,112,112,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[26,112,112,64]{3,2,1,0}, f16[128,3,3,64]{3,2,1,0}, f16[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:23:52.406893: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.508998875s
# Trying algorithm eng0{} for conv (f16[26,112,112,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[26,112,112,64]{3,2,1,0}, f16[128,3,3,64]{3,2,1,0}, f16[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:24:02.316282: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[3,224,224,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[3,224,224,64]{3,2,1,0}, f16[64,3,3,64]{3,2,1,0}, f16[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-08-05 20:24:02.342202: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.025997002s
# Trying algorithm eng0{} for conv (f16[3,224,224,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[3,224,224,64]{3,2,1,0}, f16[64,3,3,64]{3,2,1,0}, f16[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# Epoch 1: val_loss_0_1 = 0.46364083886146545, val_accuracy_0_1 = 0.7929077744483948
#
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 267s 454ms/step - accuracy: 0.7820 - loss: 1.4924 - val_accuracy: 0.9946 - val_loss: 0.0132
# Epoch 2/10
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9907 - loss: 0.0277
# Epoch 2: val_loss_0_1 = 0.27871471643447876, val_accuracy_0_1 = 0.8666666746139526
#
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 69s 178ms/step - accuracy: 0.9907 - loss: 0.0277 - val_accuracy: 0.9971 - val_loss: 0.0103
# Epoch 3/10
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9959 - loss: 0.0149
# Epoch 3: val_loss_0_1 = 0.24763397872447968, val_accuracy_0_1 = 0.8799054622650146
#
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 69s 178ms/step - accuracy: 0.9959 - loss: 0.0149 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 4/10
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9971 - loss: 0.0091
# Epoch 4: val_loss_0_1 = 0.6467435956001282, val_accuracy_0_1 = 0.7981087565422058
#
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 69s 177ms/step - accuracy: 0.9971 - loss: 0.0091 - val_accuracy: 0.9990 - val_loss: 0.0027
# Epoch 5/10
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9965 - loss: 0.0094
# Epoch 5: val_loss_0_1 = 0.8428830504417419, val_accuracy_0_1 = 0.7049645185470581
#
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 69s 177ms/step - accuracy: 0.9965 - loss: 0.0094 - val_accuracy: 0.9990 - val_loss: 0.0033
# Epoch 6/10
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9973 - loss: 0.0066
# Epoch 6: val_loss_0_1 = 0.3111417889595032, val_accuracy_0_1 = 0.8808510899543762
#
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 69s 177ms/step - accuracy: 0.9973 - loss: 0.0066 - val_accuracy: 0.9990 - val_loss: 0.0035
# Epoch 7/10
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9992 - loss: 0.0028
# Epoch 7: val_loss_0_1 = 1.599902629852295, val_accuracy_0_1 = 0.6302600502967834
#
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 69s 177ms/step - accuracy: 0.9992 - loss: 0.0028 - val_accuracy: 0.9990 - val_loss: 0.0020
# Epoch 8/10
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9986 - loss: 0.0038
# Epoch 8: val_loss_0_1 = 0.8724892735481262, val_accuracy_0_1 = 0.7635933756828308
#
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 69s 177ms/step - accuracy: 0.9986 - loss: 0.0038 - val_accuracy: 0.9990 - val_loss: 0.0019
# Epoch 9/10
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9998 - loss: 7.5744e-04
# Epoch 9: val_loss_0_1 = 1.0847722291946411, val_accuracy_0_1 = 0.7300236225128174
#
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 69s 177ms/step - accuracy: 0.9998 - loss: 7.5738e-04 - val_accuracy: 0.9995 - val_loss: 0.0015
# Epoch 10/10
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9971 - loss: 0.0074
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 10: val_loss_0_1 = 0.595698893070221, val_accuracy_0_1 = 0.7862884402275085
#
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 76s 196ms/step - accuracy: 0.9971 - loss: 0.0074 - val_accuracy: 0.9995 - val_loss: 0.0011
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.9994 - loss: 0.0012
# Test Loss on 2&3: 0.0010845671640709043
# Test Accuracy on 2&3: 0.9995102882385254
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8339 - loss: 0.4645
# Validation Loss on 0&1: 0.595698893070221
# Validation Accuracy on 0&1: 0.7862884402275085
#    epoch  accuracy  val_accuracy      loss  val_loss  val_loss_0_1  \
# 0      1  0.917032      0.994613  0.463605  0.013233      0.463641
# 1      2  0.991645      0.997062  0.024653  0.010347      0.278715
# 2      3  0.995202      1.000000  0.015395  0.002422      0.247634
# 3      4  0.997353      0.999021  0.008007  0.002710      0.646744
# 4      5  0.997105      0.999021  0.007777  0.003322      0.842883
# 5      6  0.997849      0.999021  0.005338  0.003471      0.311142
# 6      7  0.999256      0.999021  0.002695  0.002006      1.599903
# 7      8  0.998676      0.999021  0.004236  0.001864      0.872489
# 8      9  0.999752      0.999510  0.000734  0.001539      1.084772
# 9     10  0.998428      0.999510  0.004407  0.001085      0.595699
#
#    val_accuracy_0_1
# 0          0.792908
# 1          0.866667
# 2          0.879905
# 3          0.798109
# 4          0.704965
# 5          0.880851
# 6          0.630260
# 7          0.763593
# 8          0.730024
# 9          0.786288
